# %%
## FUEL, LANDING FEES, AIF together
import gurobipy as gp
from gurobipy import GRB

airports = ['M', 'T', 'W', 'V', 'H']  

# Distance between airports in km
distances = {
    ('H', 'M'): 804,
    ('H', 'T'): 1288,
    ('M', 'T'): 507,
    ('M', 'W'): 1818,
    ('M', 'V'): 3682,
    ('T', 'W'): 1504,
    ('T', 'V'): 3345,
    ('W', 'V'): 1864,
}

# Fuel price at departing airport
fuel_prices = {
    'H': 1.28,
    'M': 1.17,
    'T': 1.29,
    'W': 1.19,
    'V': 1.30,
}

# Landing fees at airports
landing_fees = {
    "Halifax": 11.29,
    "Montreal": 11.64,
    "Toronto": 18.97,
    "Winnipeg": 7.50,
    "Vancouver": 7.98,
}

# Airport Improvement Fee (AIF) per passenger for each airport
aif_rates = {
    "Halifax": 28,
    "Montreal": 35,
    "Toronto": 30,
    "Winnipeg": 25,
    "Vancouver": 25,
}

## Added by Vivek
# Helper function to calculate fuel cost
def calculate_fuel_cost(arc):
    """
    Calculate the fuel cost of traveling along a given arc (route).
    """
    # Extract departure and arrival city codes
    depart_city = arc[0]  # Departure city is the first character
    arrive_city = arc.split("-")[1][0]  # Arrival city is the first character after the hyphen

    # Exclude arcs involving sink nodes, layover nodes, or invalid city codes (*)
    if depart_city == "t" or arrive_city == "t" or "*" in depart_city or "*" in arrive_city:
        return 0  # No fuel cost for sink arcs or layover nodes

    # Validate that departure and arrival cities are in the list of airports
    if depart_city not in airports or arrive_city not in airports:
        print(f"Warning: Invalid city code in arc {arc}")
        return 0

    # Calculate fuel cost as the product of distance and fuel price
    distance = distances.get((depart_city, arrive_city), 0) or distances.get((arrive_city, depart_city), 0)
    fuel_price = fuel_prices[depart_city]
    return distance * fuel_price

## Added by Vivek
# Helper function to calculate landing fee based on destination
def get_landing_fee(arc):
    """
    Returns the landing fee for the destination city in the given arc.
    """
    destination = arc.split("-")[1][0]  # Get the destination city code
    city_map = {'H': 'Halifax', 'M': 'Montreal', 'T': 'Toronto', 'W': 'Winnipeg', 'V': 'Vancouver'}
    return landing_fees.get(city_map.get(destination, ""), 0)  # Default to 0 if invalid city

## Added by Vivek
# Helper function to calculate AIF based on departure city
def get_aif(arc):
    """
    Returns the Airport Improvement Fee (AIF) for the departure city in the given arc.
    """
    departure = arc[0]  # Get the departure city code
    city_map = {'H': 'Halifax', 'M': 'Montreal', 'T': 'Toronto', 'W': 'Winnipeg', 'V': 'Vancouver'}
    return aif_rates.get(city_map.get(departure, ""), 0)  # Default to 0 if invalid city


'''
Processing data
'''

# File containing passenger demands (days are separated by: "end")
f_demands = open("/Users/vivek.persad/Downloads/demands.txt", "r")  
demand_data = f_demands.readlines()
f_demands.close()

# File containing ticket revenues data
f_revenues = open("/Users/vivek.persad/Downloads/ticket_revenues.txt", "r")  
rev_data = f_revenues.readlines()
f_revenues.close()

# Cities by table index are given by:
table_index = {'H': 0, 'M': 1, 'T': 2, 'W': 3, 'V': 4}

# Reading the demands data
day_total = 0               # total number of passengers flying in one day
total_daily_demands = []    # list of total number of passengers flying by day
day_demands_matrix = []     # matrix of passenger demands for one day
demands_matrix = []         # list of daily demands matrices

for line_num in range(len(demand_data)):
    row = demand_data[line_num].split(",")
    if row == ["end\n"] or row == ["end"]:  # End of data for this day
        demands_matrix.append(day_demands_matrix)
        day_demands_matrix = []
        total_daily_demands.append(day_total)
        day_total = 0
    else:
        row = list(map(lambda x: int(x), row))
        day_total += sum(row)
        day_demands_matrix.append(row)

# Reading the revenue data
revenues_matrix = []
for line_num in range(0, len(rev_data)):
    row = rev_data[line_num].split(",")
    revenues_matrix.append(list(map(lambda x: int(x), row)))


'''
# Building the digraph

'''
cities = ['V', 'W', 'T', 'M', 'H']
arc_set = [] + ['T*-H', 'M*-H']  # form: each arc (i,j) is a string: "i-j"

for i in cities:
    arc_set.append(i + '-' + 't')
    for j in cities:
        if i != j:
            if i == 'T' or i == 'M':
                arc_set.append(i + j + '-' + j)
                arc_set.append(i + j + '-' + 't')
            elif i == 'V' or i == 'W':
                if j == 'H':
                    arc_set.append(i + j + '-' + 'T*') 
                    arc_set.append(i + j + '-' + 'M*')
                    arc_set.append(i + j + '-' + 't')
                else:
                    arc_set.append(i + j + '-' + j)
                    arc_set.append(i + j + '-' +'t')
            else: #i = 'H'
                if j == 'T' or j == 'M':
                    arc_set.append('H' + j + '-' + j)
                    arc_set.append(i + j + '-' + 't')
                elif j == 'W' or j == 'V': 
                    arc_set.append('H' + j + '-' + 'T*'), arc_set.append('T*' + '-' + j)
                    arc_set.append('H' + j + '-' + 'M*'), arc_set.append('M*' + '-' + j)
                    arc_set.append(i + j + '-' + 't')
print(arc_set) # Haviva added
node_set = cities.copy() + ['T*', 'M*', 't']
for i in cities:
    for j in cities:
        if i != j:
            node_set.append(i + j)


'''
# Building the model
'''

FLIGHTS_MODEL = gp.Model("Passenger_Demands")

# Variables - by arc and day
X = FLIGHTS_MODEL.addVars(arc_set, [0,1,2,3,4], vtype=GRB.CONTINUOUS, lb=0, ub=float('inf'), name="x")
n = FLIGHTS_MODEL.addVars(arc_set, [0, 1, 2, 3, 4], vtype=GRB.INTEGER, lb=0, name="n") # This is the total numberof flights flying from city i to j on day k

plane_capacity = 211  # Plane capacity of B767

# Objective
obj_fn = 0
for day_num in range(0,5):
    for arc in arc_set:
        depart = arc.split("-")[0][0]
        arrive = arc.split("-")[1][0]

        if arrive != "t":  # then the arc has some cost
            revenue = revenues_matrix[table_index[depart]][table_index[arrive]] * X[arc, day_num]
            fuel_cost = calculate_fuel_cost(arc) * n[arc, day_num] # Added by Vivek fuel cost
            landing_cost = get_landing_fee(arc) * n[arc, day_num] # Added by Vivek landing costs
            aif_cost = get_aif(arc) * X[arc, day_num]  # Added by Vivek AIF applied per passenger
            cost = fuel_cost + landing_cost + aif_cost # edited overall cost calculation
            obj_fn += revenue - cost

FLIGHTS_MODEL.setObjective(obj_fn, GRB.MAXIMIZE)

# Flow conservation constraints - by node and day
for day_num in range(0,5):
    for v in node_set:
        v_demand = 0
        if v == 't': # the sink node
            v_demand = total_daily_demands[day_num]
        elif (len(v) == 1) or (v == 'T*') or (v=='M*'): # a destination node
            v_demand = 0
        else:  # a supply node
            depart = list(v)[0]   # starting city
            arrive = list(v)[1]   # destination city
            v_demand = -1 * demands_matrix[day_num][table_index[depart]][table_index[arrive]]

        v_constraint = 0
        for arc in arc_set:
            if v == arc.split("-")[0]: # outgoing arc from v
                v_constraint += -1 * X[arc,day_num]
            elif v == arc.split("-")[1]: # incoming arc to v
                v_constraint += X[arc,day_num]
        
        FLIGHTS_MODEL.addConstr(v_constraint == v_demand, name=f"flow_{v}_{day_num}")


## Haviva part added for capacity constraints
# Capacity constraints
for day_num in range(0, 5):
    for arc in arc_set:
        if 't' not in arc:  # Ignore sink arcs
            FLIGHTS_MODEL.addConstr(
                X[arc, day_num] <= plane_capacity * n[arc, day_num],
                name="capacity_" + arc + "_" + str(day_num)
            )

# Profit constraints
for day_num in range(0, 5):
    for arc in arc_set:
        if 't' not in arc:  # Ignore sink arcs
            ticket_price = revenues_matrix[table_index[arc.split("-")[0][0]]][table_index[arc.split("-")[1][0]]]
            operating_cost = cost * n[arc, day_num]
            FLIGHTS_MODEL.addConstr(
                operating_cost <= ticket_price * X[arc, day_num],
                name="profit_" + arc + "_" + str(day_num)
            )


# Run the model
FLIGHTS_MODEL.optimize()

# Output
for day_num in range(0, 5):
    print(f"\nDay {day_num}:")
    for arc in arc_set:
        x_value = X[arc, day_num].X
        n_value = n[arc, day_num].X
        if x_value > 0 or n_value > 0:
            print(f"Arc {arc}, Day {day_num}: Passengers = {x_value}, Flights = {n_value}")
# Out:
# ['T*-H', 'M*-H', 'V-t', 'VW-W', 'VW-t', 'VT-T', 'VT-t', 'VM-M', 'VM-t', 'VH-T*', 'VH-M*', 'VH-t', 'W-t', 'WV-V', 'WV-t', 'WT-T', 'WT-t', 'WM-M', 'WM-t', 'WH-T*', 'WH-M*', 'WH-t', 'T-t', 'TV-V', 'TV-t', 'TW-W', 'TW-t', 'TM-M', 'TM-t', 'TH-H', 'TH-t', 'M-t', 'MV-V', 'MV-t', 'MW-W', 'MW-t', 'MT-T', 'MT-t', 'MH-H', 'MH-t', 'H-t', 'HV-T*', 'T*-V', 'HV-M*', 'M*-V', 'HV-t', 'HW-T*', 'T*-W', 'HW-M*', 'M*-W', 'HW-t', 'HT-T', 'HT-t', 'HM-M', 'HM-t']
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[x86] - Darwin 22.6.0 22H221)
#
# CPU model: Intel(R) Core(TM) i5-7360U CPU @ 2.30GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 290 rows, 550 columns and 850 nonzeros
# Model fingerprint: 0x74d795fd
# Model has 150 quadratic constraints
# Variable types: 275 continuous, 275 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   QMatrix range    [3e+01, 1e+03]
#   QLMatrix range   [1e+02, 3e+02]
#   Objective range  [9e+01, 5e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 3e+04]
# Presolve removed 105 rows and 230 columns
# Presolve time: 0.01s
# Presolved: 932 rows, 621 columns, 1825 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Presolved model has 298 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
#
# Solving non-convex MIQCP
#
# Variable types: 321 continuous, 300 integer (0 binary)
#
# Root relaxation: objective 2.602356e+07, 42 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.6024e+07    0  327          - 2.6024e+07      -     -    0s
#      0     0 2.5919e+07    0  254          - 2.5919e+07      -     -    0s
#      0     0 2.5903e+07    0  239          - 2.5903e+07      -     -    0s
#      0     0 2.5901e+07    0  252          - 2.5901e+07      -     -    0s
#      0     0 2.5901e+07    0  252          - 2.5901e+07      -     -    0s
#      0     0 2.5901e+07    0  255          - 2.5901e+07      -     -    0s
#      0     0 2.5901e+07    0  255          - 2.5901e+07      -     -    0s
# H    0     0                    2.576363e+07 2.5901e+07  0.53%     -    0s
# H    0     0                    2.577663e+07 2.5901e+07  0.48%     -    0s
#      0     2 2.5901e+07    0  369 2.5777e+07 2.5901e+07  0.48%     -    0s
# H   39    88                    2.579943e+07 2.5900e+07  0.39%  12.0    0s
# H   65    88                    2.580729e+07 2.5900e+07  0.36%   9.4    0s
# H   74    88                    2.586630e+07 2.5900e+07  0.13%   8.7    0s
# H  119   129                    2.587155e+07 2.5900e+07  0.11%   8.0    0s
# *  163   132              23    2.587241e+07 2.5900e+07  0.11%   7.6    0s
# *  167   132              24    2.587565e+07 2.5900e+07  0.09%   7.4    0s
# *  407   199              25    2.587760e+07 2.5899e+07  0.08%   6.4    0s
# H  438   163                    2.588451e+07 2.5899e+07  0.06%   6.5    0s
# H  491   150                    2.588858e+07 2.5889e+07  0.00%   7.1    1s
#
# Cutting planes:
#   Gomory: 12
#   MIR: 49
#   Network: 1
#   RLT: 34
#
# Explored 491 nodes (4100 simplex iterations) in 1.74 seconds (0.48 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 2.58886e+07 2.58845e+07 2.58776e+07 ... 2.57766e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.588858057000e+07, best bound 2.588869523070e+07, gap 0.0004%
#
# Day 0:
# Arc T*-H, Day 0: Passengers = 1739.0, Flights = 9.0
# Arc V-t, Day 0: Passengers = 5717.0, Flights = 0.0
# Arc VW-W, Day 0: Passengers = 633.0, Flights = 3.0
# Arc VW-t, Day 0: Passengers = 60.0, Flights = 0.0
# Arc VT-T, Day 0: Passengers = 1730.0, Flights = 9.0
# Arc VM-M, Day 0: Passengers = 719.0, Flights = 4.0
# Arc VH-M*, Day 0: Passengers = 1169.0, Flights = 6.0
# Arc W-t, Day 0: Passengers = 2146.0, Flights = 0.0
# Arc WV-V, Day 0: Passengers = 729.0, Flights = 4.0
# Arc WT-T, Day 0: Passengers = 1290.0, Flights = 7.0
# Arc WM-M, Day 0: Passengers = 199.0, Flights = 1.0
# Arc WH-M*, Day 0: Passengers = 984.0, Flights = 5.0
# Arc T-t, Day 0: Passengers = 7868.0, Flights = 0.0
# Arc TV-V, Day 0: Passengers = 1951.0, Flights = 10.0
# Arc TW-W, Day 0: Passengers = 1135.0, Flights = 6.0
# Arc TM-M, Day 0: Passengers = 3584.0, Flights = 17.0
# Arc TH-H, Day 0: Passengers = 1462.0, Flights = 7.0
# Arc M-t, Day 0: Passengers = 5135.0, Flights = 0.0
# Arc MV-V, Day 0: Passengers = 716.0, Flights = 4.0
# Arc MW-W, Day 0: Passengers = 378.0, Flights = 2.0
# Arc MT-T, Day 0: Passengers = 3288.0, Flights = 16.0
# Arc MH-H, Day 0: Passengers = 1064.0, Flights = 6.0
# Arc H-t, Day 0: Passengers = 4265.0, Flights = 0.0
# Arc HV-T*, Day 0: Passengers = 1236.0, Flights = 6.0
# Arc M*-V, Day 0: Passengers = 2321.0, Flights = 11.0
# Arc HW-T*, Day 0: Passengers = 503.0, Flights = 3.0
# Arc HW-M*, Day 0: Passengers = 168.0, Flights = 1.0
# Arc HT-T, Day 0: Passengers = 1560.0, Flights = 8.0
# Arc HM-M, Day 0: Passengers = 633.0, Flights = 3.0
# Arc HM-t, Day 0: Passengers = 2.0, Flights = 0.0
#
# Day 1:
# Arc T*-H, Day 1: Passengers = 1427.0, Flights = 7.0
# Arc V-t, Day 1: Passengers = 5330.0, Flights = 0.0
# Arc VW-W, Day 1: Passengers = 733.0, Flights = 4.0
# Arc VT-T, Day 1: Passengers = 1800.0, Flights = 9.0
# Arc VM-M, Day 1: Passengers = 633.0, Flights = 3.0
# Arc VM-t, Day 1: Passengers = 1.0, Flights = 0.0
# Arc VH-M*, Day 1: Passengers = 1217.0, Flights = 6.0
# Arc W-t, Day 1: Passengers = 2082.0, Flights = 0.0
# Arc WV-V, Day 1: Passengers = 513.0, Flights = 3.0
# Arc WT-T, Day 1: Passengers = 1032.0, Flights = 5.0
# Arc WM-M, Day 1: Passengers = 493.0, Flights = 3.0
# Arc WH-M*, Day 1: Passengers = 830.0, Flights = 4.0
# Arc T-t, Day 1: Passengers = 8049.0, Flights = 0.0
# Arc TV-V, Day 1: Passengers = 1794.0, Flights = 9.0
# Arc TW-W, Day 1: Passengers = 1086.0, Flights = 6.0
# Arc TM-M, Day 1: Passengers = 3383.0, Flights = 17.0
# Arc TH-H, Day 1: Passengers = 1529.0, Flights = 8.0
# Arc M-t, Day 1: Passengers = 5346.0, Flights = 0.0
# Arc MV-V, Day 1: Passengers = 702.0, Flights = 4.0
# Arc MW-W, Day 1: Passengers = 263.0, Flights = 2.0
# Arc MT-T, Day 1: Passengers = 3561.0, Flights = 17.0
# Arc MH-H, Day 1: Passengers = 780.0, Flights = 4.0
# Arc H-t, Day 1: Passengers = 3736.0, Flights = 0.0
# Arc HV-T*, Day 1: Passengers = 827.03125, Flights = 4.0
# Arc HV-M*, Day 1: Passengers = 184.96875, Flights = 1.0
# Arc M*-V, Day 1: Passengers = 2321.0, Flights = 11.0
# Arc HW-T*, Day 1: Passengers = 599.96875, Flights = 3.0
# Arc HW-M*, Day 1: Passengers = 89.03125, Flights = 1.0
# Arc HT-T, Day 1: Passengers = 1656.0, Flights = 8.0
# Arc HM-M, Day 1: Passengers = 837.0, Flights = 4.0
#
# Day 2:
# Arc T*-H, Day 2: Passengers = 2026.0, Flights = 10.0
# Arc V-t, Day 2: Passengers = 5185.0, Flights = 0.0
# Arc VW-W, Day 2: Passengers = 539.0, Flights = 3.0
# Arc VT-T, Day 2: Passengers = 1833.0, Flights = 9.0
# Arc VM-M, Day 2: Passengers = 771.0, Flights = 4.0
# Arc VH-M*, Day 2: Passengers = 1234.0, Flights = 6.0
# Arc W-t, Day 2: Passengers = 2349.0, Flights = 0.0
# Arc WV-V, Day 2: Passengers = 544.0, Flights = 3.0
# Arc WT-T, Day 2: Passengers = 1094.0, Flights = 6.0
# Arc WM-M, Day 2: Passengers = 496.0, Flights = 3.0
# Arc WH-M*, Day 2: Passengers = 755.0, Flights = 4.0
# Arc T-t, Day 2: Passengers = 7935.0, Flights = 0.0
# Arc TV-V, Day 2: Passengers = 1749.0, Flights = 9.0
# Arc TW-W, Day 2: Passengers = 1337.0, Flights = 7.0
# Arc TM-M, Day 2: Passengers = 3582.0, Flights = 17.0
# Arc TH-H, Day 2: Passengers = 1495.0, Flights = 8.0
# Arc M-t, Day 2: Passengers = 5611.0, Flights = 0.0
# Arc MV-V, Day 2: Passengers = 782.0, Flights = 4.0
# Arc MW-W, Day 2: Passengers = 473.0, Flights = 3.0
# Arc MT-T, Day 2: Passengers = 3320.0, Flights = 16.0
# Arc MH-H, Day 2: Passengers = 784.0, Flights = 4.0
# Arc H-t, Day 2: Passengers = 4305.0, Flights = 0.0
# Arc HV-T*, Day 2: Passengers = 1237.0, Flights = 6.0
# Arc M*-V, Day 2: Passengers = 2110.0, Flights = 10.0
# Arc HW-T*, Day 2: Passengers = 789.0, Flights = 4.0
# Arc HW-M*, Day 2: Passengers = 121.0, Flights = 1.0
# Arc HT-T, Day 2: Passengers = 1688.0, Flights = 8.0
# Arc HT-t, Day 2: Passengers = 6.0, Flights = 0.0
# Arc HM-M, Day 2: Passengers = 762.0, Flights = 4.0
#
# Day 3:
# Arc T*-H, Day 3: Passengers = 2016.0, Flights = 10.0
# Arc V-t, Day 3: Passengers = 5234.0, Flights = 0.0
# Arc VW-W, Day 3: Passengers = 633.0, Flights = 3.0
# Arc VW-t, Day 3: Passengers = 12.0, Flights = 0.0
# Arc VT-T, Day 3: Passengers = 1666.0, Flights = 8.0
# Arc VM-M, Day 3: Passengers = 835.0, Flights = 4.0
# Arc VH-M*, Day 3: Passengers = 1111.0, Flights = 6.0
# Arc W-t, Day 3: Passengers = 2183.0, Flights = 0.0
# Arc WV-V, Day 3: Passengers = 726.0, Flights = 4.0
# Arc WT-T, Day 3: Passengers = 1136.0, Flights = 6.0
# Arc WM-M, Day 3: Passengers = 561.0, Flights = 3.0
# Arc WH-M*, Day 3: Passengers = 896.0, Flights = 5.0
# Arc T-t, Day 3: Passengers = 7697.0, Flights = 0.0
# Arc TV-V, Day 3: Passengers = 1742.0, Flights = 9.0
# Arc TW-W, Day 3: Passengers = 1302.0, Flights = 7.0
# Arc TM-M, Day 3: Passengers = 3426.0, Flights = 17.0
# Arc TH-H, Day 3: Passengers = 1605.0, Flights = 8.0
# Arc M-t, Day 3: Passengers = 5575.0, Flights = 0.0
# Arc MV-V, Day 3: Passengers = 759.0, Flights = 4.0
# Arc MW-W, Day 3: Passengers = 248.0, Flights = 2.0
# Arc MT-T, Day 3: Passengers = 3418.0, Flights = 17.0
# Arc MH-H, Day 3: Passengers = 784.0, Flights = 4.0
# Arc H-t, Day 3: Passengers = 4405.0, Flights = 0.0
# Arc HV-T*, Day 3: Passengers = 1226.0, Flights = 6.0
# Arc M*-V, Day 3: Passengers = 2007.0, Flights = 10.0
# Arc HW-T*, Day 3: Passengers = 790.0, Flights = 4.0
# Arc HT-T, Day 3: Passengers = 1477.0, Flights = 7.0
# Arc HM-M, Day 3: Passengers = 753.0, Flights = 4.0
#
# Day 4:
# Arc T*-H, Day 4: Passengers = 1614.0, Flights = 8.0
# Arc V-t, Day 4: Passengers = 4883.0, Flights = 0.0
# Arc VW-W, Day 4: Passengers = 757.0, Flights = 4.0
# Arc VT-T, Day 4: Passengers = 1785.0, Flights = 9.0
# Arc VM-M, Day 4: Passengers = 824.0, Flights = 4.0
# Arc VH-M*, Day 4: Passengers = 979.0, Flights = 5.0
# Arc W-t, Day 4: Passengers = 2010.0, Flights = 0.0
# Arc WV-V, Day 4: Passengers = 621.0, Flights = 3.0
# Arc WT-T, Day 4: Passengers = 1157.0, Flights = 6.0
# Arc WM-M, Day 4: Passengers = 401.0, Flights = 2.0
# Arc WH-M*, Day 4: Passengers = 674.0, Flights = 4.0
# Arc T-t, Day 4: Passengers = 8020.0, Flights = 0.0
# Arc TV-V, Day 4: Passengers = 1686.0, Flights = 8.0
# Arc TW-W, Day 4: Passengers = 963.0, Flights = 5.0
# Arc TM-M, Day 4: Passengers = 3425.0, Flights = 17.0
# Arc TH-H, Day 4: Passengers = 1596.0, Flights = 8.0
# Arc M-t, Day 4: Passengers = 5250.74, Flights = 0.0
# Arc MV-V, Day 4: Passengers = 923.0, Flights = 5.0
# Arc MW-W, Day 4: Passengers = 290.0, Flights = 2.0
# Arc MT-T, Day 4: Passengers = 3572.0, Flights = 17.0
# Arc MH-H, Day 4: Passengers = 783.0, Flights = 4.0
# Arc H-t, Day 4: Passengers = 3993.0, Flights = 0.0
# Arc HV-T*, Day 4: Passengers = 931.0, Flights = 5.0
# Arc M*-V, Day 4: Passengers = 1653.0, Flights = 8.0
# Arc HW-T*, Day 4: Passengers = 683.0, Flights = 4.0
# Arc HT-T, Day 4: Passengers = 1506.0, Flights = 8.0
# Arc HM-M, Day 4: Passengers = 600.74, Flights = 3.0
# Arc HM-t, Day 4: Passengers = 84.25999999999999, Flights = 0.0
